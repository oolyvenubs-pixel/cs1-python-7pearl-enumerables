# %% [markdown]
# <a href="https://colab.research.google.com/github/oolyvenubs-pixel/cs1-python-7pearl-enumerables/blob/main/CS2ILA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("I am Phanbin")
# Out:
# I am Phanbin
